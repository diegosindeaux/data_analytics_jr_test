# %% [markdown]
# Vou tratar apenas de 2016 para a frente, que é a data que temos dados da outra tabela

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/Escolas/escolasr34.csv', delimiter=';')

# %%
data.head()
# Out:
#   DRE  CODESC TIPOESC                              NOMESC DIRETORIA  \
# 0  BT  200758     CCA                   CCA - UNIDADE III   BUTANTA
# 1  BT  200417     CCA  CENTRO JUVENIL SALESIANO DOM BOSCO   BUTANTA
# 2  BT  200399     CCA                  CLARICE FERRAZ WEY   BUTANTA
# 3  BT  200270     CCA              EDUCANDARIO DOM DUARTE   BUTANTA
# 4  BT  200402     CCA             FREI LUIZ AMIGO - CEFLA   BUTANTA
#
#      SUBPREF  CEU                                    ENDERECO NUMERO  \
# 0    BUTANTA  NaN                 RUA EUDORO LINCOLN BERLINCK    346
# 1  PINHEIROS  NaN                                  RUA PIO XI   1380
# 2    BUTANTA  NaN                     RUA CARLANTONIO CARLONE    102
# 3    BUTANTA  NaN  AVENIDA DOUTOR HEITOR ANTONIO EIRAS GARCIA   5985
# 4    BUTANTA  NaN                       RUA LUIZ LOPEZ COELHO    300
#
#               BAIRRO  ...  DTURNOS12 DTURNOS11 DTURNOS10 DTURNOS09 DTURNOS08  \
# 0    JARDIM ARPOADOR  ...        NaN       NaN       NaN       NaN       NaN
# 1       ALTO DA LAPA  ...        NaN       NaN       NaN       NaN       NaN
# 2   JARDIM JAQUELINE  ...        NaN       NaN       NaN       NaN       NaN
# 3   JARDIM ESMERALDA  ...        NaN       NaN       NaN       NaN       NaN
# 4  JARDIM CENTENARIO  ...        NaN       NaN       NaN       NaN       NaN
#
#    DTURNOS07    LATITUDE   LONGITUDE  REDE    DATABASE
# 0        NaN -23595965.0 -46792261.0   NaN  30/09/2016
# 1        NaN -23540346.0 -46716525.0   NaN  30/09/2016
# 2        NaN -23592064.0 -46752447.0   NaN  30/09/2016
# 3        NaN -23607320.0 -46803792.0   NaN  30/09/2016
# 4        NaN -23576084.0 -46749293.0   NaN  30/09/2016
#
# [5 rows x 51 columns]

# %%
blank_columns = data.isnull().all(axis=0)
blank_total = blank_columns.sum()
blank_total
# Out:
# np.int64(0)

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# DIRETORIA       object
# SUBPREF         object
# CEU             object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_FUNC     object
# DT_AUTORIZA     object
# NOME_ANT        object
# T2D3D           object
# T2D3D15         object
# T2D3D14         object
# T2D3D13         object
# T2D3D12         object
# T2D3D11         object
# T2D3D10         object
# T2D3D09         object
# T2D3D08         object
# T2D3D07         object
# DTURNOS         object
# DTURNOS15       object
# DTURNOS14       object
# DTURNOS13       object
# DTURNOS12       object
# DTURNOS11       object
# DTURNOS10       object
# DTURNOS09       object
# DTURNOS08       object
# DTURNOS07       object
# LATITUDE       float64
# LONGITUDE      float64
# REDE            object
# DATABASE        object
# dtype: object

# %%
data.drop(['T2D3D', 'T2D3D07', 'T2D3D08', 'T2D3D09', 'T2D3D10', 'T2D3D11', 'T2D3D12', 'T2D3D13', 'T2D3D14', 'T2D3D15',
                 'DTURNOS', 'DTURNOS07', 'DTURNOS08', 'DTURNOS09', 'DTURNOS10', 'DTURNOS11', 'DTURNOS12', 'DTURNOS13', 'DTURNOS14', 'DTURNOS15'], axis=1, inplace=True)

# %%
data.head()
# Out:
#   DRE  CODESC TIPOESC                              NOMESC DIRETORIA  \
# 0  BT  200758     CCA                   CCA - UNIDADE III   BUTANTA
# 1  BT  200417     CCA  CENTRO JUVENIL SALESIANO DOM BOSCO   BUTANTA
# 2  BT  200399     CCA                  CLARICE FERRAZ WEY   BUTANTA
# 3  BT  200270     CCA              EDUCANDARIO DOM DUARTE   BUTANTA
# 4  BT  200402     CCA             FREI LUIZ AMIGO - CEFLA   BUTANTA
#
#      SUBPREF  CEU                                    ENDERECO NUMERO  \
# 0    BUTANTA  NaN                 RUA EUDORO LINCOLN BERLINCK    346
# 1  PINHEIROS  NaN                                  RUA PIO XI   1380
# 2    BUTANTA  NaN                     RUA CARLANTONIO CARLONE    102
# 3    BUTANTA  NaN  AVENIDA DOUTOR HEITOR ANTONIO EIRAS GARCIA   5985
# 4    BUTANTA  NaN                       RUA LUIZ LOPEZ COELHO    300
#
#               BAIRRO  ...  DT_CRIACAO       ATO_CRIACAO DOM_CRIACAO  \
# 0    JARDIM ARPOADOR  ...  01/03/2015      201401543991  01/03/2015
# 1       ALTO DA LAPA  ...  01/04/2013  2013.0.002.139.6  01/04/2013
# 2   JARDIM JAQUELINE  ...  01/04/2013  2013.0.002.135.3  01/04/2013
# 3   JARDIM ESMERALDA  ...  01/04/2013  2013.0.002.155.8  01/04/2013
# 4  JARDIM CENTENARIO  ...  01/04/2013  2013.0.002.167.1  01/04/2013
#
#   DT_INI_FUNC DT_AUTORIZA  NOME_ANT    LATITUDE   LONGITUDE  REDE    DATABASE
# 0         NaN         NaN       NaN -23595965.0 -46792261.0   NaN  30/09/2016
# 1         NaN         NaN       NaN -23540346.0 -46716525.0   NaN  30/09/2016
# 2         NaN         NaN       NaN -23592064.0 -46752447.0   NaN  30/09/2016
# 3         NaN         NaN       NaN -23607320.0 -46803792.0   NaN  30/09/2016
# 4         NaN         NaN       NaN -23576084.0 -46749293.0   NaN  30/09/2016
#
# [5 rows x 31 columns]

# %%
data.to_csv('data/Escolas/escolasr34T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolasr34dez2017.csv', delimiter=';')

# %%
data.head()
# Out:
#   DRE  CODESC TIPOESC                                NOMESC  \
# 0   G      86    EMEI            PAULO CAMILHIER FLORENCANO
# 1  FO      94    EMEI                VICENTE PAULO DA SILVA
# 2  MP     108    EMEF          JOSE ERMIRIO DE MORAIS, SEN.
# 3  BT     191    EMEF             ALIPIO CORREA NETO, PROF.
# 4  PJ     205   EMEBS  VERA LUCIA APARECIDA RIBEIRO, PROFA.
#
#                DIRETORIA                  SUBPREF  CEU  \
# 0             GUAIANASES               GUAIANASES  NaN
# 1  FREGUESIA/BRASILANDIA  CASA VERDE/CACHOEIRINHA  NaN
# 2             SAO MIGUEL               SAO MIGUEL  NaN
# 3                BUTANTA                  BUTANTA  NaN
# 4               PIRITUBA                 PIRITUBA  NaN
#
#                      ENDERECO  NUMERO                        BAIRRO  ...  \
# 0   RUA FELICIANO DE MENDONÇA  502     JARDIM SÃO PAULO(ZONA LESTE)  ...
# 1  RUA DOUTOR FLEURY SILVEIRA  295                 VILA SANTA MARIA  ...
# 2      RUA SAO BRAS DO SUACUI  159                    JARDIM HELENA  ...
# 3        AVENIDA JOAO CAIAFFA  140                    JARDIM TABOAO  ...
# 4        RUA BENEDITO PEREIRA  206                    JARDIM LIBANO  ...
#
#    DTURNOS12 DTURNOS11 DTURNOS10 DTURNOS09 DTURNOS08  DTURNOS07    LATITUDE  \
# 0         MT        MT        MT       MIV       MIV         MT -23553905.0
# 1         MT        MT        MT       MIV       MIV        MIV -23489728.0
# 2        MTN       MTN       MTN       MTN      MIVN       MIVN -23478312.0
# 3         MT        MT        MT        MT        MT        MTN -23612237.0
# 4        MTN       MTN       MTN       MTN       MTN        MTN -23486142.0
#
#     LONGITUDE  REDE   DATABASE
# 0 -46398452.0   DIR  28-dez-17
# 1 -46670198.0   DIR  28-dez-17
# 2 -46427344.0   DIR  28-dez-17
# 3 -46749888.0   DIR  28-dez-17
# 4 -46733901.0   DIR  28-dez-17
#
# [5 rows x 53 columns]

# %%
data.drop(['T2D3D', 'T2D3D07', 'T2D3D08', 'T2D3D09', 'T2D3D10', 'T2D3D11', 'T2D3D12', 'T2D3D13', 'T2D3D14', 'T2D3D15', 'T2D3D16',
           'DTURNOS', 'DTURNOS07', 'DTURNOS08', 'DTURNOS09', 'DTURNOS10', 'DTURNOS11', 'DTURNOS12', 'DTURNOS13', 
           'DTURNOS14', 'DTURNOS15', 'DTURNOS16'], axis=1, inplace=True)

# %%
data.head()
# Out:
#   DRE  CODESC TIPOESC                                NOMESC  \
# 0   G      86    EMEI            PAULO CAMILHIER FLORENCANO
# 1  FO      94    EMEI                VICENTE PAULO DA SILVA
# 2  MP     108    EMEF          JOSE ERMIRIO DE MORAIS, SEN.
# 3  BT     191    EMEF             ALIPIO CORREA NETO, PROF.
# 4  PJ     205   EMEBS  VERA LUCIA APARECIDA RIBEIRO, PROFA.
#
#                DIRETORIA                  SUBPREF  CEU  \
# 0             GUAIANASES               GUAIANASES  NaN
# 1  FREGUESIA/BRASILANDIA  CASA VERDE/CACHOEIRINHA  NaN
# 2             SAO MIGUEL               SAO MIGUEL  NaN
# 3                BUTANTA                  BUTANTA  NaN
# 4               PIRITUBA                 PIRITUBA  NaN
#
#                      ENDERECO  NUMERO                        BAIRRO  ...  \
# 0   RUA FELICIANO DE MENDONÇA  502     JARDIM SÃO PAULO(ZONA LESTE)  ...
# 1  RUA DOUTOR FLEURY SILVEIRA  295                 VILA SANTA MARIA  ...
# 2      RUA SAO BRAS DO SUACUI  159                    JARDIM HELENA  ...
# 3        AVENIDA JOAO CAIAFFA  140                    JARDIM TABOAO  ...
# 4        RUA BENEDITO PEREIRA  206                    JARDIM LIBANO  ...
#
#    DT_CRIACAO ATO_CRIACAO DOM_CRIACAO DT_INI_FUNC DT_AUTORIZA  \
# 0   13-jun-88      26.134   13-jun-88   22-set-88   16-mar-91
# 1   04-jul-88      26.314   04-jul-88   01-ago-88   16-mar-91
# 2   05-jul-88      26.312   05-jul-88   01-set-88   13-mar-01
# 3   27-mai-88      26.003   27-mai-88   02-out-88   16-mar-91
# 4   22-jun-88      26.229   22-jun-88   19-set-88   16-mar-91
#
#               NOME_ANT    LATITUDE   LONGITUDE  REDE   DATABASE
# 0                  NaN -23553905.0 -46398452.0   DIR  28-dez-17
# 1                  NaN -23489728.0 -46670198.0   DIR  28-dez-17
# 2  VILA NITRO OPERARIA -23478312.0 -46427344.0   DIR  28-dez-17
# 3                  NaN -23612237.0 -46749888.0   DIR  28-dez-17
# 4                  NaN -23486142.0 -46733901.0   DIR  28-dez-17
#
# [5 rows x 31 columns]

# %%
data['DATABASE'] = '28/12/2017'

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# DIRETORIA       object
# SUBPREF         object
# CEU             object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_FUNC     object
# DT_AUTORIZA     object
# NOME_ANT        object
# LATITUDE       float64
# LONGITUDE      float64
# REDE            object
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolasr34dez2017T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolas122018.csv', delimiter=';')

# %%
data.head()
# Out:
#   ï»¿dre  codesc       tipoesc                                nomesc  ceu  \
# 0     BT     191  EMEF                      ALIPIO CORREA NETO, PROF  NaN
# 1     BT     213  EMEI          ANTONIO CARLOS PACHECO E SILVA, PROF  NaN
# 2     BT     477  EMEF           PROFA. EDA TEREZINHA CHICA MEDEIROS  NaN
# 3     BT   11924  EMEF               PROFA. MARIA ALICE BORGES GHION  NaN
# 4     BT   14591  EMEI                     PROF. BENEDICTO CASTRUCCI  NaN
#
#                                 diretoria  subpref  \
# 0  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 1  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 2  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 3  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 4  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
#
#                         endereco  numero                            bairro  \
# 0           Avenida JOAO CAIAFFA     140                     JARDIM TABOAO
# 1        Avenida JOÃÆO CAIAFFA      90                  JARDIM TABOÃÆO
# 2  Rua ENGENHEIRO HUGO TAKAHASHI     333                    RAPOSO TAVARES
# 3       Rua CACHOEIRA PORAQUÃÅ      575  CONJUNTO PROMORAR RAPOSO TAVARES
# 4          Rua CACHOEIRA PORAQUE  S/N     CONJUNTO PROMORAR RAPOSO TAVARES
#
#    ...  doc_criacao  dt_ini_conv dt_ini_func  dt_autoriza dt_extintao  \
# 0  ...   27/05/1988          NaN  02/10/1988   16/03/1991         NaN
# 1  ...   07/06/1988          NaN  26/09/1988   13/03/2001         NaN
# 2  ...   26/10/1988          NaN  20/02/1989   16/03/1991         NaN
# 3  ...   17/02/1992          NaN  20/02/1992   13/03/2001         NaN
# 4  ...   02/03/1994          NaN  13/04/1994   13/03/2001         NaN
#
#                                 nome_ant rede     latitude    longitude  \
# 0              ALIPIO CORREA NETO, PROF.  DIR  -23.612.237  -46.749.888
# 1  ANTONIO CARLOS PACHECO E SILVA, PROF.  DIR  -23.611.929  -46.750.176
# 2   EDA TEREZINHA CHICA MEDEIROS, PROFA.  DIR  -23.602.076  -46.783.825
# 3       MARIA ALICE BORGES GHION, PROFA.  DIR  -23.586.959  -46.801.039
# 4      CONJ. HABITACIONAL RAPOSO TAVARES  DIR  -23.586.339  -46.800.967
#
#      database
# 0  30/12/2018
# 1  30/12/2018
# 2  30/12/2018
# 3  30/12/2018
# 4  30/12/2018
#
# [5 rows x 34 columns]

# %%
print(data.dtypes)
# Out:
# ï»¿dre          object
# codesc           int64
# tipoesc         object
# nomesc          object
# ceu             object
# diretoria       object
# subpref         object
# endereco        object
# numero          object
# bairro          object
# cep              int64
# tel1           float64
# tel2            object
# fax            float64
# situacao        object
# coddist          int64
# distrito        object
# setor            int64
# codinep        float64
# cd_cie         float64
# eh              object
# fx_etaria       object
# dt_criacao      object
# ato_criacao     object
# doc_criacao     object
# dt_ini_conv     object
# dt_ini_func     object
# dt_autoriza     object
# dt_extintao     object
# nome_ant        object
# rede            object
# latitude        object
# longitude       object
# database        object
# dtype: object

# %%
data.rename(columns={'ï»¿dre' : 'DRE',
                     'codesc' : 'CODESC',
                     'tipoesc' : 'TIPOESC',
                     'nomesc' : 'NOMESC',
                     'ceu' : 'CEU',
                     'diretoria' : 'DIRETORIA',
                     'subpref' : 'SUBPREF',
                     'endereco' : 'ENDERECO',
                     'numero' : 'NUMERO',
                     'bairro' : 'BAIRRO',
                     'cep' : 'CEP',
                     'tel1' : 'TEL1',
                     'tel2' : 'TEL2',
                     'fax' : 'FAX',
                     'situacao' : 'SITUACAO',
                     'coddist' : 'CODDIST',
                     'distrito' : 'DISTRITO',
                     'setor' : 'SETOR',
                     'codinep' : 'CODINEP',
                     'cd_cie' : 'CODCIE',
                     'eh' : 'EH',
                     'fx_etaria' : 'FX_ETARIA',
                     'dt_criacao' : 'DT_CRIACAO',
                     'ato_criacao' : 'ATO_CRIACAO',
                     'doc_criacao' : 'DOM_CRIACAO',
                     'dt_ini_conv' : 'DT_INI_CONV',
                     'dt_ini_func' : 'DT_INI_FUNC',
                     'dt_autoriza' : 'DT_AUTORIZA',
                     'dt_extintao' : 'DT_EXTINCAO',
                     'nome_ant' : 'NOME_ANT',
                     'rede' : 'REDE',
                     'latitude' : 'LATITUDE',
                     'longitude' : 'LONGITUDE',
                     'database' : 'DATABASE',
                    }, inplace=True)

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1           float64
# TEL2            object
# FAX            float64
# SITUACAO        object
# CODDIST          int64
# DISTRITO        object
# SETOR            int64
# CODINEP        float64
# CODCIE         float64
# EH              object
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_INI_FUNC     object
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE        object
# LONGITUDE       object
# DATABASE        object
# dtype: object

# %%
data['LATITUDE'] = pd.to_numeric(data['LATITUDE'], errors='coerce')
data['LONGITUDE'] = pd.to_numeric(data['LONGITUDE'], errors='coerce')
data['EH'] = pd.to_numeric(data['EH'], errors='coerce')
data['SETOR'] = data['SETOR'].astype(float)
data['CODDIST'] = data['CODDIST'].astype(float)
data['TEL1'] = data['TEL1'].astype(object)
data['FAX'] = data['FAX'].astype(object)

# Entendo que tem algumas coisas que deveriam ser de outro tipo, mas pelo enunciado do desafio
# tinha que seguir o mesmo formato de dados.



print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_INI_FUNC     object
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE       float64
# LONGITUDE      float64
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolas122018T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolas122019.csv', delimiter=';')

# %%
data.head()
# Out:
#   ï»¿dre  codesc tipoesc                                nomesc  ceu  \
# 0     BT     191    EMEF              ALIPIO CORREA NETO, PROF  NaN
# 1     BT     213    EMEI  ANTONIO CARLOS PACHECO E SILVA, PROF  NaN
# 2     BT     477    EMEF   PROFA. EDA TEREZINHA CHICA MEDEIROS  NaN
# 3     BT   11924    EMEF       PROFA. MARIA ALICE BORGES GHION  NaN
# 4     BT   14591    EMEI             PROF. BENEDICTO CASTRUCCI  NaN
#
#                                 diretoria  subpref  \
# 0  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 1  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 2  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 3  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
# 4  DIRETORIA REGIONAL DE EDUCACAO BUTANTA  BUTANTA
#
#                         endereco  numero                            bairro  \
# 0           Avenida JOAO CAIAFFA     140                     JARDIM TABOAO
# 1          Avenida JOÃO CAIAFFA      90                    JARDIM TABOÃO
# 2  Rua ENGENHEIRO HUGO TAKAHASHI     333                    RAPOSO TAVARES
# 3         Rua CACHOEIRA PORAQUÃ     575  CONJUNTO PROMORAR RAPOSO TAVARES
# 4          Rua CACHOEIRA PORAQUE  S/N     CONJUNTO PROMORAR RAPOSO TAVARES
#
#    ...  dom_criacao  dt_ini_conv dt_ini_func  dt_autoriza dt_extintao  \
# 0  ...   27/05/1988          NaN  02/10/1988   16/03/1991         NaN
# 1  ...   07/06/1988          NaN  26/09/1988   13/03/2001         NaN
# 2  ...   26/10/1988          NaN  20/02/1989   16/03/1991         NaN
# 3  ...   17/02/1992          NaN  20/02/1992   13/03/2001         NaN
# 4  ...   02/03/1994          NaN  13/04/1994   13/03/2001         NaN
#
#                                 nome_ant rede     latitude    longitude  \
# 0              ALIPIO CORREA NETO, PROF.  DIR  -23.612.237  -46.749.888
# 1  ANTONIO CARLOS PACHECO E SILVA, PROF.  DIR  -23.611.929  -46.750.176
# 2   EDA TEREZINHA CHICA MEDEIROS, PROFA.  DIR  -23.602.076  -46.783.825
# 3                   COHAB RAPOSO TAVARES  DIR  -23.586.959  -46.801.039
# 4      CONJ. HABITACIONAL RAPOSO TAVARES  DIR  -23.586.339  -46.800.967
#
#      database
# 0  01/12/2019
# 1  01/12/2019
# 2  01/12/2019
# 3  01/12/2019
# 4  01/12/2019
#
# [5 rows x 34 columns]

# %%
data.rename(columns={'ï»¿dre' : 'DRE',
                     'codesc' : 'CODESC',
                     'tipoesc' : 'TIPOESC',
                     'nomesc' : 'NOMESC',
                     'ceu' : 'CEU',
                     'diretoria' : 'DIRETORIA',
                     'subpref' : 'SUBPREF',
                     'endereco' : 'ENDERECO',
                     'numero' : 'NUMERO',
                     'bairro' : 'BAIRRO',
                     'cep' : 'CEP',
                     'tel1' : 'TEL1',
                     'tel2' : 'TEL2',
                     'fax' : 'FAX',
                     'situacao' : 'SITUACAO',
                     'coddist' : 'CODDIST',
                     'distrito' : 'DISTRITO',
                     'setor' : 'SETOR',
                     'codinep' : 'CODINEP',
                     'cd_cie' : 'CODCIE',
                     'eh' : 'EH',
                     'fx_etaria' : 'FX_ETARIA',
                     'dt_criacao' : 'DT_CRIACAO',
                     'ato_criacao' : 'ATO_CRIACAO',
                     'doc_criacao' : 'DOM_CRIACAO',
                     'dt_ini_conv' : 'DT_INI_CONV',
                     'dt_ini_func' : 'DT_INI_FUNC',
                     'dt_autoriza' : 'DT_AUTORIZA',
                     'dt_extintao' : 'DT_EXTINCAO',
                     'nome_ant' : 'NOME_ANT',
                     'rede' : 'REDE',
                     'latitude' : 'LATITUDE',
                     'longitude' : 'LONGITUDE',
                     'database' : 'DATABASE',
                    }, inplace=True)

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1           float64
# TEL2            object
# FAX            float64
# SITUACAO        object
# CODDIST          int64
# DISTRITO        object
# SETOR            int64
# CODINEP        float64
# CODCIE         float64
# EH              object
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# dom_criacao     object
# DT_INI_CONV     object
# DT_INI_FUNC     object
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE        object
# LONGITUDE       object
# DATABASE        object
# dtype: object

# %%
data['LATITUDE'] = pd.to_numeric(data['LATITUDE'], errors='coerce')
data['LONGITUDE'] = pd.to_numeric(data['LONGITUDE'], errors='coerce')
data['EH'] = pd.to_numeric(data['EH'], errors='coerce')
data['SETOR'] = data['SETOR'].astype(float)
data['CODDIST'] = data['CODDIST'].astype(float)
data['TEL1'] = data['TEL1'].astype(object)
data['FAX'] = data['FAX'].astype(object)

print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# dom_criacao     object
# DT_INI_CONV     object
# DT_INI_FUNC     object
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE       float64
# LONGITUDE      float64
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolas122019T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolas122020.csv', delimiter=';')

# %%
data.head()
# Out:
#   dre  codesc tipoesc                                 nomesc  \
# 0  BT     191    EMEF              ALIPIO CORREA NETO, PROF.
# 1  BT     213    EMEI  ANTONIO CARLOS PACHECO E SILVA, PROF.
# 2  BT     477    EMEF   EDA TEREZINHA CHICA MEDEIROS, PROFA.
# 3  BT   11924    EMEF       MARIA ALICE BORGES GHION, PROFA.
# 4  BT   14591    EMEI             BENEDICTO CASTRUCCI, PROF.
#
#                               nomescofi  CEU diretoria  subpref  \
# 0              ALIPIO CORREA NETO, PROF  NaN   BUTANTA  BUTANTA
# 1  ANTONIO CARLOS PACHECO E SILVA, PROF  NaN   BUTANTA  BUTANTA
# 2   PROFA. EDA TEREZINHA CHICA MEDEIROS  NaN   BUTANTA  BUTANTA
# 3       PROFA. MARIA ALICE BORGES GHION  NaN   BUTANTA  BUTANTA
# 4             PROF. BENEDICTO CASTRUCCI  NaN   BUTANTA  BUTANTA
#
#                         ENDERECO  NUMERO  ... ATO_CRIACAO       DOM_CRIACAO  \
# 0           AVENIDA JOAO CAIAFFA     140  ...      26.003  27/05/1988 00:00
# 1           AVENIDA JOÃO CAIAFFA      90  ...      26.117  07/06/1988 00:00
# 2  RUA ENGENHEIRO HUGO TAKAHASHI     333  ...      27.212  26/10/1988 00:00
# 3          RUA CACHOEIRA PORAQUÊ     575  ...      31.240  17/02/1992 00:00
# 4          RUA CACHOEIRA PORAQUE  S/N     ...      34.005  02/03/1994 00:00
#
#   DT_INI_CONV       DT_AUTORIZA dt_extincao  \
# 0         NaN  16/03/1991 00:00         NaN
# 1         NaN  13/03/2001 00:00         NaN
# 2         NaN  16/03/1991 00:00         NaN
# 3         NaN  13/03/2001 00:00         NaN
# 4         NaN  13/03/2001 00:00         NaN
#
#                             NOME_ANT  REDE  LATITUDE  LONGITUDE  \
# 0                                NaN   DIR -23612237  -46749888
# 1                                NaN   DIR -23611929  -46750176
# 2                 JARDIM EDUCANDARIO   DIR -23602076  -46783825
# 3               COHAB RAPOSO TAVARES   DIR -23586959  -46801039
# 4  CONJ. HABITACIONAL RAPOSO TAVARES   DIR -23586339  -46800967
#
#            DATABASE
# 0  31/12/2020 00:00
# 1  31/12/2020 00:00
# 2  31/12/2020 00:00
# 3  31/12/2020 00:00
# 4  31/12/2020 00:00
#
# [5 rows x 34 columns]

# %%
print(data.dtypes)
# Out:
# dre             object
# codesc           int64
# tipoesc         object
# nomesc          object
# nomescofi       object
# CEU             object
# diretoria       object
# subpref         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# coddist          int64
# distrito        object
# setor            int64
# codinep        float64
# cd_cie         float64
# eh              object
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_AUTORIZA     object
# dt_extincao    float64
# NOME_ANT        object
# REDE            object
# LATITUDE         int64
# LONGITUDE        int64
# DATABASE        object
# dtype: object

# %%
data.rename(columns={'dre' : 'DRE',
                     'codesc' : 'CODESC',
                     'tipoesc' : 'TIPOESC',
                     'nomesc' : 'NOMESC',
                     'diretoria' : 'DIRETORIA',
                     'subpref' : 'SUBPREF',
                     'coddist' : 'CODDIST',
                     'distrito' : 'DISTRITO',
                     'setor' : 'SETOR',
                     'codinep' : 'CODINEP',
                     'cd_cie' : 'CODCIE',
                     'eh' : 'EH',
                     'dt_extincao' : 'DT_EXTINCAO',
                    }, inplace=True)

data.drop(['nomescofi'], axis=1, inplace=True)

data['LATITUDE'] = data['LATITUDE'].astype(float)
data['LONGITUDE'] = data['LONGITUDE'].astype(float)
data['EH'] = pd.to_numeric(data['EH'], errors='coerce')
data['SETOR'] = data['SETOR'].astype(float)
data['CODDIST'] = data['CODDIST'].astype(float)
data['TEL1'] = data['TEL1'].astype(object)
data['FAX'] = data['FAX'].astype(object)

print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_AUTORIZA     object
# DT_EXTINCAO    float64
# NOME_ANT        object
# REDE            object
# LATITUDE       float64
# LONGITUDE      float64
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolas122020T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolas122021.csv', delimiter=';')

# %%
data.head()
# Out:
#   DRE  CODESC    TIPOESC                               NOMES  \
# 0  BT  307207  ESC.PART.                          A HEBRAICA
# 1  BT  307412  ESC.PART.                          ABCD SOFIA
# 2  BT  307131  ESC.PART.                   ACONCHEGO, ESCOLA
# 3  BT  306549  ESC.PART.                    ADOLPHE FERRIERE
# 4  BT   92754       EMEF  ALCIDES GONCALVES ETCHEGOYEN, GEN.
#
#                             NOMESCOFI  CEU DIRETORIA    SUBPREF  \
# 0                          A HEBRAICA  NaN   BUTANTA  PINHEIROS
# 1                          ABCD SOFIA  NaN   BUTANTA    BUTANTA
# 2                   ACONCHEGO, ESCOLA  NaN   BUTANTA    BUTANTA
# 3                    ADOLPHE FERRIERE  NaN   BUTANTA    BUTANTA
# 4  ALCIDES GONCALVES ETCHEGOYEN, GEN.  NaN   BUTANTA    BUTANTA
#
#                    ENDERECO NUMERO  ... ATO_CRIACAO  DOM_CRIACAO DT_INI_CONV  \
# 0               RUA HUNGRIA   1000  ...           3    01/fev/10         NaN
# 1  RUA OTÁVIO PEDREIRO ROSA    212  ...          62    10/nov/10         NaN
# 2            RUA QUITANDUBA     50  ...          85    21/ago/09         NaN
# 3       RUA FRANCISCO PRETO    457  ...         NaN          NaN         NaN
# 4     RUA ADHERBAL STRESSER    686  ...       9.332    16/fev/71         NaN
#
#   DT_AUTORIZA DT_EXTINCAO  NOME_ANT  REDE  LATITUDE  LONGITUDE   DATABASE
# 0   06/fev/10         NaN       NaN   PAR -23578930  -46694078  31/dez/21
# 1   12/nov/10         NaN       NaN   PAR -23583388  -46760545  31/dez/21
# 2         NaN         NaN       NaN   PAR -23583061  -46715523  31/dez/21
# 3   21/out/03         NaN       NaN   PAR -23603215  -46726799  31/dez/21
# 4   10/abr/81         NaN  ARPOADOR   DIR -23594749  -46791369  31/dez/21
#
# [5 rows x 34 columns]

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMES           object
# NOMESCOFI       object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST          int64
# DISTRITO        object
# SETOR            int64
# CODINEP          int64
# CD_CIE         float64
# EH              object
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE         int64
# LONGITUDE        int64
# DATABASE        object
# dtype: object

# %%
data.rename(columns={'CD_CIE' : 'CODCIE'}, inplace=True)

data['DATABASE'] = '31/12/2021'

data.drop(['NOMESCOFI', 'DT_CRIACAO', 'DT_INI_CONV', 'DT_AUTORIZA', 'DT_EXTINCAO', 'DOM_CRIACAO'], axis=1, inplace=True)
data['LATITUDE'] = data['LATITUDE'].astype(float)
data['LONGITUDE'] = data['LONGITUDE'].astype(float)
data['EH'] = pd.to_numeric(data['EH'], errors='coerce')
data['SETOR'] = data['SETOR'].astype(float)
data['CODDIST'] = data['CODDIST'].astype(float)
data['CODINEP'] = data['CODINEP'].astype(float)


print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMES           object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# FX_ETARIA       object
# ATO_CRIACAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE       float64
# LONGITUDE      float64
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolas122021T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolas122022.csv', delimiter=';')

# %%
data.head()
# Out:
#   DRE  CODESC    TIPOESC                                NOMES  \
# 0  BT  307207  ESC.PART.                           A HEBRAICA
# 1  BT  307412  ESC.PART.                           ABCD SOFIA
# 2  BT  307131  ESC.PART.                    ACONCHEGO, ESCOLA
# 3  BT  400003  CEI DIRET  ALOYSIO DE MENEZES GREENHALGH, VER.
# 4  BT   92754       EMEF   ALCIDES GONCALVES ETCHEGOYEN, GEN.
#
#                              NOMESCOFI  CEU DIRETORIA    SUBPREF  \
# 0                           A HEBRAICA  NaN   BUTANTA  PINHEIROS
# 1                           ABCD SOFIA  NaN   BUTANTA    BUTANTA
# 2                    ACONCHEGO, ESCOLA  NaN   BUTANTA    BUTANTA
# 3  ALOYSIO DE MENEZES GREENHALGH, VER.  NaN   BUTANTA    BUTANTA
# 4   ALCIDES GONCALVES ETCHEGOYEN, GEN.  NaN   BUTANTA    BUTANTA
#
#                     ENDERECO NUMERO  ... ATO_CRIACAO  DOM_CRIACAO DT_INI_CONV  \
# 0                RUA HUNGRIA   1000  ...           3   01/02/2010         NaN
# 1   RUA OTÁVIO PEDREIRO ROSA    212  ...          62   10/11/2010         NaN
# 2             RUA QUITANDUBA     50  ...          85   21/08/2009         NaN
# 3  RUA DOUTOR FRANCISCO PATI    375  ...      24.765   16/10/1987         NaN
# 4      RUA ADHERBAL STRESSER    686  ...       9.332   16/02/1971         NaN
#
#   DT_AUTORIZA DT_EXTINCAO            NOME_ANT  REDE  LATITUDE  LONGITUDE  \
# 0   06/fev/10         NaN                 NaN   NaN -23578930  -46694078
# 1   12/nov/10         NaN                 NaN   NaN -23583388  -46760545
# 2         NaN         NaN                 NaN   NaN -23583061  -46715523
# 3   22/mai/07         NaN  VILA SAO FRANCISCO   NaN -23557659  -46759414
# 4   10/abr/81         NaN            ARPOADOR   NaN -23594749  -46791369
#
#      DATABASE
# 0  31/12/2022
# 1  31/12/2022
# 2  31/12/2022
# 3  31/12/2022
# 4  31/12/2022
#
# [5 rows x 34 columns]

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMES           object
# NOMESCOFI       object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST          int64
# DISTRITO        object
# SETOR            int64
# CODINEP        float64
# CD_CIE         float64
# EH              object
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_AUTORIZA     object
# DT_EXTINCAO    float64
# NOME_ANT        object
# REDE           float64
# LATITUDE         int64
# LONGITUDE        int64
# DATABASE        object
# dtype: object

# %%
data.rename(columns={'CD_CIE' : 'CODCIE'}, inplace=True)
data.drop(['NOMESCOFI'], axis=1, inplace=True)

data['LATITUDE'] = data['LATITUDE'].astype(float)
data['LONGITUDE'] = data['LONGITUDE'].astype(float)
data['REDE'] = data['REDE'].astype(object)
data['EH'] = pd.to_numeric(data['EH'], errors='coerce')
data['SETOR'] = data['SETOR'].astype(float)
data['CODDIST'] = data['CODDIST'].astype(float)
data['DT_EXTINCAO'] = data['DT_EXTINCAO'].astype(object)

print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMES           object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# CODDIST        float64
# DISTRITO        object
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# FX_ETARIA       object
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV     object
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# REDE            object
# LATITUDE       float64
# LONGITUDE      float64
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolas122022T.csv', index=False, sep=';', encoding='utf-8')

# %%
data = pd.read_csv('data/Escolas/escolas122023.csv', delimiter=';')

# %%
data.head()
# Out:
#   DRE  CODESC TIPOESC                                 NOMES  \
# 0   G      86    EMEI            PAULO CAMILHIER FLORENCANO
# 1  FO      94    EMEI                VICENTE PAULO DA SILVA
# 2  MP     108    EMEF          JOSE ERMIRIO DE MORAES, SEN.
# 3  BT     191    EMEF             ALIPIO CORREA NETO, PROF.
# 4  PJ     205   EMEBS  VERA LUCIA APARECIDA RIBEIRO, PROFA.
#
#                                  DESLOC  CEU              DIRETORIA  \
# 0            PAULO CAMILHIER FLORENCANO  NaN             GUAIANASES
# 1                VICENTE PAULO DA SILVA  NaN  FREGUESIA/BRASILANDIA
# 2          JOSE ERMIRIO DE MORAES, SEN.  NaN             SAO MIGUEL
# 3             ALIPIO CORREA NETO, PROF.  NaN                BUTANTA
# 4  VERA LUCIA APARECIDA RIBEIRO, PROFA.  NaN               PIRITUBA
#
#                    SUBPREF                    ENDERECO NUMERO  ...  \
# 0               GUAIANASES   RUA FELICIANO DE MENDONCA    502  ...
# 1  CASA VERDE/CACHOEIRINHA  RUA DOUTOR FLEURY SILVEIRA    295  ...
# 2               SAO MIGUEL      RUA SAO BRAS DO SUACUI    159  ...
# 3                  BUTANTA        AVENIDA JOAO CAIAFFA    140  ...
# 4                 PIRITUBA        RUA BENEDITO PEREIRA    206  ...
#
#   ATO_CRIACAO  DOM_CRIACAO DT_INI_CONV DT_AUTORIZA DT_EXTINCAO FX_ETARIA.1  \
# 0      26.134   13/06/1988         NaN  16/03/1991         NaN         NaN
# 1      26.314   04/07/1988         NaN  16/03/1991         NaN         NaN
# 2      26.312   05/07/1988         NaN  13/03/2001         NaN         NaN
# 3      26.003   27/05/1988         NaN  16/03/1991         NaN         NaN
# 4      26.229   22/06/1988         NaN  16/03/1991         NaN         NaN
#
#               NOME_ANT  LATITUDE  LONGITUDE    DATABASE
# 0                  NaN -23553905  -46398452  25/12/2023
# 1                  NaN -23489728  -46670198  25/12/2023
# 2  VILA NITRO OPERARIA -23478312  -46427344  25/12/2023
# 3                  NaN -23612237  -46749888  25/12/2023
# 4                  NaN -23486142  -46733901  25/12/2023
#
# [5 rows x 34 columns]

# %%
print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMES           object
# DESLOC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# DISTRITO        object
# CDIST            int64
# SETOR            int64
# CODINEP        float64
# CD_CIE         float64
# EH              object
# FX_ETARIA      float64
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV    float64
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# FX_ETARIA.1     object
# NOME_ANT        object
# LATITUDE         int64
# LONGITUDE        int64
# DATABASE        object
# dtype: object

# %%
data.rename(columns={'CDIST' : 'CODDIST',
                     'CD_CIE' : 'CODCIE',
                     'NOMES' : 'NOMESC'
                    }, inplace=True)

data.drop(['DESLOC', 'FX_ETARIA.1'], axis=1, inplace=True)

data['LATITUDE'] = data['LATITUDE'].astype(float)
data['LONGITUDE'] = data['LONGITUDE'].astype(float)
data['EH'] = pd.to_numeric(data['EH'], errors='coerce')
data['SETOR'] = data['SETOR'].astype(float)
data['CODDIST'] = data['CODDIST'].astype(float)
data['DT_EXTINCAO'] = data['DT_EXTINCAO'].astype(object)

print(data.dtypes)
# Out:
# DRE             object
# CODESC           int64
# TIPOESC         object
# NOMESC          object
# CEU             object
# DIRETORIA       object
# SUBPREF         object
# ENDERECO        object
# NUMERO          object
# BAIRRO          object
# CEP              int64
# TEL1            object
# TEL2            object
# FAX             object
# SITUACAO        object
# DISTRITO        object
# CODDIST        float64
# SETOR          float64
# CODINEP        float64
# CODCIE         float64
# EH             float64
# FX_ETARIA      float64
# DT_CRIACAO      object
# ATO_CRIACAO     object
# DOM_CRIACAO     object
# DT_INI_CONV    float64
# DT_AUTORIZA     object
# DT_EXTINCAO     object
# NOME_ANT        object
# LATITUDE       float64
# LONGITUDE      float64
# DATABASE        object
# dtype: object

# %%
data.to_csv('data/Escolas/escolas122023T.csv', index=False, sep=';', encoding='utf-8')
